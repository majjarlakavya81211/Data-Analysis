# %%
#M.kavya
#2211cs010344
#group-4

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel("MIDMARKS.xlsx")
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.plot()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  691 non-null    object
#  2   DV       718 non-null    int32
#  3   M-II     718 non-null    int32
#  4   PP       718 non-null    int32
#  5   BEEE     718 non-null    int32
#  6   FL       718 non-null    int32
#  7   FIMS     718 non-null    int32
# dtypes: float64(1), int32(6), object(1)
# memory usage: 28.2+ KB

# %%
df[df['DV'].isnull()]
# Out:
#       S.NO SECTION   DV M-II   PP BEEE   FL FIMS
# 564  565.0   SIGMA  NaN  NaN  NaN  NaN  NaN  NaN
# 601    NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
df.head()
# Out:
#    S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0   1.0   ALPHA  12    0  17    9  19   15
# 1   2.0   ALPHA  19   12  16   16  18    3
# 2   3.0   ALPHA  18   14  18   18  18   16
# 3   4.0   ALPHA  15    9  19   17  19   15
# 4   5.0   ALPHA  18   17  19   19  20   18

# %%
df.tail()
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
columns_to_convert = ["DV", "M-II", "PP", "BEEE", "FL", "FIMS"]
for col in columns_to_convert: 
    df[col]=pd.to_numeric(df[col], errors='coerce')
df["Total"] = df["DV"] + df["M-II"] + df["PP"] + df["BEEE"] + df["FL"] + df["FIMS"]
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0
#
# [718 rows x 9 columns]

# %%
df["Percentage"]=df.Total/60 *100
df.fillna(0,inplace=True)

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
# [718 rows x 10 columns]

# %%
def assign_grade(percentage):
    if percentage >= 90:
        return 'A'
    elif percentage >= 80:
        return 'B'
    elif percentage >= 70:
        return 'C'
    elif percentage >= 60:
        return 'D'
    else:
        return 'F'

df['Grade'] = df['Percentage'].apply(assign_grade)

df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage Grade
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000     A
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000     A
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000     A
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667     A
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000     A
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...   ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333     A
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667     A
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333     A
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333     B
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000     A
#
# [718 rows x 11 columns]

# %%
def assign_grade(PP):
    if PP >= 18:
        return 'very good'
    elif PP>= 15:
        return 'good'
    elif PP >= 13:
        return 'average'
    else:
        return 'poor'

df['Performance'] = df['PP'].apply(assign_grade)

df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance
# 0       A        good
# 1       A        good
# ...

# %%
df['DV'] = pd.to_numeric(df['DV'], errors='coerce')
def assign_grade(DV):
    if DV >= 18:
        return 'Very Good'
    elif DV >=15:
        return 'Good'
    elif DV >=13:
        return 'Average'
    else:
        return 'Poor'

df['performance_DV'] = df['DV'].apply(assign_grade)
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance performance_DV
# 0       A        good           Poor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S.NO            718 non-null    float64
#  1   SECTION         718 non-null    object
#  2   DV              718 non-null    float64
#  3   M-II            718 non-null    float64
#  4   PP              718 non-null    float64
#  5   BEEE            718 non-null    float64
#  6   FL              718 non-null    float64
#  7   FIMS            718 non-null    float64
#  8   Total           718 non-null    float64
#  9   Percentage      718 non-null    float64
#  10  Grade           718 non-null    object
#  11  Performance     718 non-null    object
#  12  performance_DV  718 non-null    object
# dtypes: float64(9), object(4)
# memory usage: 73.1+ KB

# %%
df=df.dropna(subset=['DV'])

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance performance_DV
# 0       A        good           Poor
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
plt.figure(figsize=[8, 6])
plt.hist(df['Total'], color='blue', bins=9, edgecolor='black')
plt.title("Distribution of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Number of Students")
plt.show()

# %%
average_total_by_section = df.groupby('SECTION')['Total'].mean()
print("Average Total Marks by Section:")
print(average_total_by_section)
# Out:
# Average Total Marks by Section:
# SECTION
# 0          84.111111
# ALPHA      86.600000
# BETA       80.644444
# DELTA      74.622222
# EPSILON    72.295455
# GAMMA      75.177778
# OMEGA      82.011111
# SIGMA      84.730159
# ZETA       72.811111
# Name: Total, dtype: float64

# %%
plt.figure(figsize=[5, 6])
average_total_by_section.plot(kind='bar', color='black')
plt.title("Average Total Marks by Section")
plt.xlabel("Average Total Marks")
plt.ylabel("Section")
plt.show()

# %%
subject_averages = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean()
print("Averages of Each Subject's Scores:")
print(subject_averages)
# Out:
# Averages of Each Subject's Scores:
# DV      14.746518
# M-II     9.922006
# PP      12.733983
# BEEE    13.250696
# FL      15.501393
# FIMS    14.008357
# dtype: float64

# %%
plt.figure(figsize=[8, 6])
subject_averages.plot(kind='bar', color='red')
plt.title("Subject-wise Average Scores")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.xticks(rotation=45)
plt.show()

# %%
average_total_by_section = df.groupby('SECTION')['Total'].mean()
plt.figure(figsize=[8,6])
average_total_by_section.plot(kind='bar', color='purple', edgecolor='white')
plt.title("Average Total Marks by Section")
plt.xlabel("Section")
plt.ylabel("Average Total Marks")
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.65)
plt.show()

# %%
subject_averages = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean()
subject_averages.plot(kind='pie', color=['blue', 'green', 'orange','purple','yellow','black'], figsize=(8, 5))
plt.title('Subject-wise Average Scores')
plt.xlabel('Subjects')
plt.ylabel('Average Score')
plt.show()

# %%
subject_averages.plot(kind='pie', autopct='%1.0f%%', color=['blue', 'green', 'orange','purple','yellow','black'], figsize=(8, 5))
plt.title('Subject-wise Average Scores')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=[8, 6])
plt.scatter(df['DV'], df['M-II'], color='blue', edgecolor='black')
plt.title("Scatter Plot: DV vs M-II Marks")
plt.xlabel("DV Marks")
plt.ylabel("M-II Marks")
plt.show()

# %%
plt.figure(figsize=[8, 6])
for section in df['SECTION'].unique():
    section_data = df[df['SECTION'] == section]
    plt.scatter(section_data['FIMS'], section_data['FL'], label=section, edgecolor='black')
    
plt.title("Scatter Plot: FIMS vs FL Marks by Section")
plt.xlabel("FIMS Marks")
plt.ylabel("FL Marks")
plt.legend(title="Sections")
plt.show()

# %%
plt.figure(figsize=[8, 6])
plt.scatter(df['Total'], df['BEEE'], color='yellow', edgecolor='black')
plt.title("Scatter Plot: Total Marks vs BEEE Marks")
plt.xlabel("Total Marks")
plt.ylabel("BEEE Marks")
plt.grid(True)
plt.show()

# %%
df["BC"]=None
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance performance_DV    BC
# 0       A        good           Poor  None
# ...

# %%
df['BC'] = (df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']] < 10).sum(axis=1)
bc = []
for i in range(len(df)):
    count = 0
    if df['DV'][i] < 10:
        count += 1
    if df['M-II'][i] < 10:
        count += 1
    if df['PP'][i] < 10:
        count += 1
    if df['BEEE'][i] < 10:
        count += 1
    if df['FL'][i] < 10:
        count += 1
    if df['FIMS'][i] < 10:
        count += 1
    bc.append(count)

df['BC'] = bc

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance performance_DV  BC
# 0       A        good           Poor   2
# ...

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="PP", y="BC", data=df,marker="o")
plt.xlabel("DV")
plt.ylabel("Total")
plt.title("BACKLOG COUNT IN DV")
plt.show()

# %%
sns.relplot(data=df,x="FIMS",y="Total")

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='PP', y='Total', data=df) 
plt.xlabel("PP")  
plt.ylabel("Total")
plt.title("BC") 
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='M-II', y='Total', data=df) 
plt.xlabel("M-II")  
plt.ylabel("Total")
plt.title("BC") 
plt.show()

# %%
df.boxplot(by='SECTION', column =['Total'],color='blue')
plt.title("Boxplot of SECTION")
plt.ylabel("Total")
plt.show()

# %%
plt.figure(figsize=(6, 4))  
sns.boxplot(x='SECTION', y='BC', data=df)  
plt.xlabel("section")  
plt.ylabel("Backlog")  
plt.title("Box Plot of Backlogs") 
plt.show()

# %%
df.Performance.value_counts()
# Out:
# Performance
# poor         328
# very good    199
# good         127
# average       64
# Name: count, dtype: int64

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance performance_DV  BC
# 0       A        good           Poor   2
# ...

# %%
subset = []
for index, row in df.iterrows():
    if (row.iloc[1:] == 20).any():
        subset.append(row)
subset_df = pd.DataFrame(subset)
print(subset_df)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# 6     7.0   ALPHA  15.0  10.0  20.0  20.0  15.0  14.0   94.0  156.666667
# 7     8.0   ALPHA  17.0  17.0  19.0  20.0  19.0  13.0  105.0  175.000000
# 8     9.0   ALPHA  10.0  18.0   0.0  20.0  19.0  15.0    0.0    0.000000
# 9    10.0   ALPHA  18.0  19.0  20.0  20.0  20.0  15.0  112.0  186.666667
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 705   0.0    ZETA  16.0   0.0  11.0  16.0  20.0   0.0    0.0    0.000000
# 709   0.0    ZETA  19.0  17.0  12.0  17.0  20.0  16.0  101.0  168.333333
# 711   0.0    ZETA  18.0   9.0  12.0  20.0  16.0  16.0   91.0  151.666667
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance performance_DV  BC
# 4       A   very good      Very Good   0
# ...

# %%
df.describe()
# Out:
#              S.NO          DV        M-II          PP        BEEE          FL  \
# count  718.000000  718.000000  718.000000  718.000000  718.000000  718.000000
# mean   251.951253   14.746518    9.922006   12.733983   13.250696   15.501393
# std    193.921102    4.629339    6.610886    5.848171    5.817407    4.544449
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     63.250000   12.000000    4.000000    9.000000    9.000000   13.000000
# 50%    242.500000   16.000000   10.000000   14.000000   15.000000   16.000000
# 75%    421.750000   18.000000   16.000000   18.000000   18.000000   20.000000
# max    601.000000   20.000000   20.000000   20.000000   20.000000   20.000000
#
#              FIMS       Total  Percentage          BC
# count  718.000000  718.000000  718.000000  718.000000
# mean    14.008357   78.605850  131.009749    1.406685
# std      4.761238   28.536049   47.560081    1.553889
# ...

# %%
df
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  Total  Percentage  \
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0  120.000000
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0  140.000000
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0  170.000000
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0  156.666667
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0  185.000000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   0.0    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0  148.333333
# 714   0.0    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   96.666667
# 715   0.0    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0  143.333333
# 716   0.0    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   88.333333
# 717   0.0    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0  175.000000
#
#     Grade Performance performance_DV  BC
# 0       A        good           Poor   2
# ...

# %%
grade_counts_students = df['BC'].value_counts()
plt.figure(figsize=(7,7))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=40, colors=['#ffcc99', '#66b3ff', '#ff9999', '#99ff99'])
plt.title('Count of Students backlogs')
plt.ylabel('')  
plt.show()

# %%
a = df['Performance'].value_counts()
plt.figure(figsize=(7,7))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=40, colors=['Skyblue','pink','green','red'])
plt.title('Performance of all students')
plt.ylabel('')  
plt.show()

# %%
a = df['performance_DV'].value_counts()
plt.figure(figsize=(7,6))
grade_counts_students.plot.pie(autopct='%1.1f%%', startangle=40, colors=['Skyblue','pink','grey','yellow'])
plt.title('Performance in DV')
plt.ylabel('')  
plt.show()

# %%
a = df['Performance'].value_counts().loc[["very good","good"]]
plt.figure(figsize=(7,7))
a.plot.pie(autopct='%1.1f%%', startangle=40, colors=['Skyblue','pink','green','red'])
plt.title('Performance of all students')
plt.ylabel('')  
plt.show()

# %%
import pandas as pd

# Load the Excel file
file_path = "MIDMARKS.xlsx"
df = pd.read_excel(file_path, sheet_name="SEM2 MID 1 - ALPHA")

# Define passing threshold
passing_marks = 10

# Convert subject columns to numeric (handling any non-numeric values)
subjects = ["DV", "M-II", "PP", "BEEE", "FL", "FIMS"]
for subject in subjects:
    df[subject] = pd.to_numeric(df[subject], errors="coerce").fillna(0)

# Convert scores to pass/fail (1 = Pass, 0 = Fail)
for subject in subjects:
    df[subject] = (df[subject] >= passing_marks).astype(int)

# Group by section and calculate pass probabilities
section_probabilities = df.groupby("SECTION")[subjects].mean() * 100  # Convert to percentage

# Create a final DataFrame with pass and fail probabilities
final_probabilities = {}
for section in section_probabilities.index:
    final_probabilities[section] = {
        subject: {
            "Pass Probability (%)": round(section_probabilities.loc[section, subject], 2),
            "Fail Probability (%)": round(100 - section_probabilities.loc[section, subject], 2)
        }
        for subject in subjects
    }

# Convert to DataFrame for better readability
section_prob_df = pd.concat(
    {k: pd.DataFrame(v).T for k, v in final_probabilities.items()}, axis=0
)

print(section_prob_df)
# Out:
#               Pass Probability (%)  Fail Probability (%)
# ALPHA   DV                   81.11                 18.89
#         M-II                 80.00                 20.00
#         PP                   86.67                 13.33
#         BEEE                 91.11                  8.89
#         FL                   98.89                  1.11
#         FIMS                 75.56                 24.44
# BETA    DV                   81.11                 18.89
#         M-II                 72.22                 27.78
#         PP                   91.11                  8.89
#         BEEE                 54.44                 45.56
#         FL                   98.89                  1.11
#         FIMS                 87.78                 12.22
# DELTA   DV                   84.44                 15.56
#         M-II                 50.00                 50.00
#         PP                   68.89                 31.11
# ...

# %%
passing_mark = 10
alpha_section = df[df['SECTION'] == 'ALPHA'].copy()  
alpha_section.loc[:, 'M-II'] = pd.to_numeric(alpha_section['M-II'], errors='coerce')
alpha_section.loc[:, 'M-II Result'] = alpha_section['M-II'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
alpha_mii_pass_fail_counts = alpha_section['M-II Result'].value_counts()
print("--- ALPHA Section: M-II Pass/Fail Counts ---")
print(alpha_mii_pass_fail_counts)
# Out:
# --- ALPHA Section: M-II Pass/Fail Counts ---
# M-II Result
# Fail    90
# Name: count, dtype: int64

# %%
passing_mark = 10
beta_section = df[df['SECTION'] == 'BETA'].copy()  
beta_section.loc[:, 'DV'] = pd.to_numeric(beta_section['DV'], errors='coerce')
beta_section.loc[:, 'DV Result'] = beta_section['DV'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
beta_dv_pass_fail_counts = beta_section['DV Result'].value_counts()

print("--- BETA Section: DV Pass/Fail Counts ---")
print(BETA_dv_pass_fail_counts)
# Out:
# --- BETA Section: DV Pass/Fail Counts ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 8
#       5 beta_dv_pass_fail_counts = beta_section['DV Result'].value_counts()
#       7 print("--- BETA Section: DV Pass/Fail Counts ---")
# ----> 8 print(BETA_dv_pass_fail_counts)
#
# NameError: name 'BETA_dv_pass_fail_counts' is not defined

# %%
passing_mark = 10
beta_section = df[df['SECTION'] == 'BETA'].copy()  
beta_section.loc[:, 'DV'] = pd.to_numeric(beta_section['DV'], errors='coerce')
beta_section.loc[:, 'DV Result'] = beta_section['DV'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
beta_dv_pass_fail_counts = beta_section['DV Result'].value_counts()

print("--- BETA Section: DV Pass/Fail Counts ---")
print(beta_dv_pass_fail_counts)  # Fixed variable name

# %%
import pandas as pd

for col in df.columns[2:]:
    df[col] = pd.to_numeric(df[col], errors='coerce')
passing_marks = 10
subject_section_pass = df.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] >= passing_marks).sum()
)
subject_section_fail = df.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] < passing_marks).sum()
)
total_students_per_section = df.groupby('SECTION').size()
prob_pass = subject_section_pass.div(total_students_per_section, axis=0)
prob_fail = subject_section_fail.div(total_students_per_section, axis=0)
print("Number of students passing each subject in each section:")
print(subject_section_pass)
print("\nNumber of students failing each subject in each section:")
print(subject_section_fail)
print("\nProbability of students passing each subject in each section:")
print(prob_pass)
print("\nProbability of students failing each subject in each section:")
print(prob_fail)

# %%
import pandas as pd
from scipy.stats import ttest_ind

# %%
print(df['DV'].dtype) 
print(df[['DV', ]].head())

# %%
df[df["SECTION"]=="BETA"]["DV"]
