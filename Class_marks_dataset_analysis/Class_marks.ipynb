# %%
# Case Study 
# CSE Group-4
# 2211CS010344
# M.Kavya

# %%
import pandas as pd
import matplotlib.pyplot as plt
s = pd.read_csv(r"C:\Users\kavya\class_marks.csv")

# %%
s
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
s.shape
# Out:
# (86, 12)

# %%
s[s.Total>30]
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# 7      34    4.0    6.0    6.0    4.0    NaN    NaN    2.0    NaN    NaN
# 9      35    2.0    4.0    5.0    4.0    5.0    5.0    NaN    NaN    NaN
# 10     37    3.0    5.0    6.0    4.0    NaN    NaN    3.0    6.0    NaN
# 12     34    4.0    4.0    5.0    3.0    2.0    2.0    2.0    1.0    9.0
# 13     32    3.0    3.0    6.0    4.0    3.0    5.0    NaN    NaN    9.0
# 15     32    3.0    NaN    2.0    1.0    5.0    5.0    3.0    7.0    NaN
# 17     36    3.0    4.0    6.0    4.0    NaN    NaN    NaN    NaN    9.0
# 21     34    4.0    6.0    5.0    3.0    5.0    5.0    NaN    3.0    NaN
# ...

# %%
s.replace(39,40).Total.value_counts()
# Out:
# Total
# 40    7
# 36    7
# 32    6
# 34    5
# 38    5
# 37    4
# 27    4
# 29    4
# 25    4
# 20    4
# 33    4
# 24    4
# 26    3
# 30    3
# 22    3
# 35    3
# 31    3
# 28    3
# 21    2
# 17    2
# 14    1
# 9     1
# 8     1
# 19    1
# 18    1
# 3     1
# Name: count, dtype: int64

# %%
s.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1     32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2     33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3     24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4     36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
#
#    Q6aM4  Q6bM6
# 0    4.0    6.0
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.0    NaN
# 4    NaN    NaN

# %%
s.tail()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 81    4.0    6.0
# 82    3.0    5.0
# 83    4.0    6.0
# 84    NaN    NaN
# 85    1.0    4.0

# %%
s=s.fillna(0)

# %%
s
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    0.0    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    0.0    0.0    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    0.0    0.0    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    0.0    0.0    0.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    0.0    0.0   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    0.0    0.0    0.0
# 82     27    2.0    2.0    5.0    3.0    0.0    0.0    0.0    0.0    7.0
# 83     37    4.0    6.0    6.0    2.0    0.0    0.0    0.0    0.0    9.0
# 84     28    4.0    0.0    5.0    4.0    5.0    4.0    0.0    0.0    6.0
# 85     29    4.0    6.0    0.0    0.0    0.0    0.0    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     0.0    0.0
# 2     0.0    0.0
# 3     2.0    0.0
# ...

# %%
s=s.astype("int64")
s
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6
# 0       4      6
# 1       0      0
# 2       0      0
# 3       2      0
# ...

# %%
s["Q1"] = s["Q1aM4"] + s["Q1bM6"]
s["Q2"] = s["Q2aM6"] + s["Q2bM4"]
s["Q3"] = s["Q3aM5"] + s["Q3bM5"]
s["Q4"] = s["Q4aM3"] + s["Q4bM7"]
s["Q5"] = s["Q5M10"]
s["Q6"] = s["Q6aM4"] + s["Q6bM6"]
s.drop(["Q1aM4", "Q1bM6","Q2aM6","Q2bM4" ,"Q3aM5" , "Q3bM5", "Q4aM3" ,"Q4bM7","Q5M10","Q6aM4","Q6bM6"], axis=1, inplace=True)

# %%
s
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6
# 0      37   9  10   3   5   8  10
# 1      32   7   7   0   9   9   0
# 2      33   9   6  10   0   8   0
# 3      24  10   9   4   0   0   2
# 4      36   9   8   9   0  10   0
# ..    ...  ..  ..  ..  ..  ..  ..
# 81     32   9   7   8   0   0  10
# 82     27   4   8   0   0   7   8
# 83     37  10   8   0   0   9  10
# 84     28   4   9   9   0   6   0
# 85     29  10   0   0   8   7   5
#
# [86 rows x 7 columns]

# %%
s["Percentage"]=s.Total/60 *100
s.fillna(0,inplace=True)

# %%
s
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6  Percentage
# 0      37   9  10   3   5   8  10   61.666667
# 1      32   7   7   0   9   9   0   53.333333
# 2      33   9   6  10   0   8   0   55.000000
# 3      24  10   9   4   0   0   2   40.000000
# 4      36   9   8   9   0  10   0   60.000000
# ..    ...  ..  ..  ..  ..  ..  ..         ...
# 81     32   9   7   8   0   0  10   53.333333
# 82     27   4   8   0   0   7   8   45.000000
# 83     37  10   8   0   0   9  10   61.666667
# 84     28   4   9   9   0   6   0   46.666667
# 85     29  10   0   0   8   7   5   48.333333
#
# [86 rows x 8 columns]

# %%
def assign_grade(percentage):
    if percentage >= 61:
        return 'A+'
    elif percentage >= 55:
        return 'A'
    elif percentage >= 45:
        return 'B+'
    elif percentage >= 30:
        return 'B'
    else:
        return 'F'

s['Grade'] = s['Percentage'].apply(assign_grade)

s
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6  Percentage Grade
# 0      37   9  10   3   5   8  10   61.666667    A+
# 1      32   7   7   0   9   9   0   53.333333    B+
# 2      33   9   6  10   0   8   0   55.000000     A
# 3      24  10   9   4   0   0   2   40.000000     B
# 4      36   9   8   9   0  10   0   60.000000     A
# ..    ...  ..  ..  ..  ..  ..  ..         ...   ...
# 81     32   9   7   8   0   0  10   53.333333    B+
# 82     27   4   8   0   0   7   8   45.000000    B+
# 83     37  10   8   0   0   9  10   61.666667    A+
# 84     28   4   9   9   0   6   0   46.666667    B+
# 85     29  10   0   0   8   7   5   48.333333    B+
#
# [86 rows x 9 columns]

# %%
grade_counts = s["Grade"].value_counts()
plt.figure(figsize=(8, 5))
grade_counts.plot(kind="bar", color="skyblue")
plt.title("Grade Distribution")
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.xticks(rotation=0)
plt.show()

# %%
s[s.Total==39]
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6  Percentage Grade
# 26     39  10   9   4   0   0  10        65.0    A+
# 49     39   9  10  10   0  10   0        65.0    A+

# %%
s.Total.count
# Out:
# <bound method Series.count of 0     37
# 1     32
# 2     33
# 3     24
# 4     36
#       ..
# 81    32
# 82    27
# 83    37
# 84    28
# 85    29
# Name: Total, Length: 86, dtype: int64>

# %%
s.Total.mean()
# Out:
# 29.36046511627907

# %%
s.plot()
plt.show()

# %%
plt.hist(s['Q1'],color='blue',edgecolor='black',bins=8)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %% [markdown]
# # It shows the scored in Q2 with maximum students got scored 10

# %%
plt.hist(s["Q2"],color='red',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %% [markdown]
# # Most of the students scores between 2 - 4 marks of Q2

# %%
plt.hist(s["Q3"],color='yellow',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# # Marks scored between 3-6 in Q4

# %%
plt.hist(s["Q4"],color='pink',bins=10,edgecolor='white')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# # The distribution shows it is near to the maximum score

# %%
plt.hist(s["Q5"],color='black',bins=10,edgecolor='white')
plt.xlabel("Marks scored in Q5")
plt.ylabel("No.of students")
plt.title("Histogram of Q5")
# Out:
# Text(0.5, 1.0, 'Histogram of Q5')

# %%
s.plot.scatter(x='Q1',y='Total',color='brown',s=40)
plt.title("20-25 Marks ANALYSIS")
plt.show()

# %% [markdown]
# # The Scatter plot of Q2 performance of overall

# %%
s.plot.scatter(x = 'Q2', y = 'Total',color='green',s=30)
plt.title("Scatter Plot for Q2")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q2')

# %% [markdown]
# # The Boxplot shows the Q6 of the students peroformance with their consistent of total

# %%
s.boxplot(by='Q6', column =['Total'], grid = False,color='blue')
plt.title("Boxplot of Q6")
plt.ylabel("Total")
plt.show()

# %%
s.boxplot(by='Q2', column =['Total'], grid = False,color='red',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The piechart shows the Q6  marks distribution

# %%
s=pd.read_csv("class_marks.csv",skiprows=70)
s
s['1.2'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q6")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q6')

# %%
s=pd.read_csv("class_marks.csv",skiprows=70)
s
s['1.1'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q5")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q5')

# %%
# Thank you Sir

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(data=s, x="Q1", y="Total")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sns.relplot(data=s, x="Q1", y="Total")
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:748, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     746         msg = "The `weights` parameter has no effect with kind='scatter'."
#     747         warnings.warn(msg, stacklevel=2)
# --> 748 p = Plotter(
#     749     data=data,
#     750     variables=variables,
#     751     legend=legend,
#     752 )
#     753 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     754 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...
